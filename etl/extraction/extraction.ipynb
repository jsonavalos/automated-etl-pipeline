# %% [markdown]
# ## Extract

# %%
# Imports
import os
import time
from datetime import datetime

import pandas as pd
from imdb import IMDb
from simplejustwatchapi.justwatch import search

# %% [markdown]
# **Get Oscar Nominees/Winners**

# %%
# https://www.kaggle.com/datasets/unanimad/the-oscar-award Can be done with API, updated yearly
data_path = "the-oscar-award/full_data.csv"

oscar_awards_df = pd.read_csv(data_path, sep="\t") 
oscar_awards_df.head()
# Out:
#    Ceremony     Year   Class          CanonicalCategory Category       NomId  \
# 0         1  1927/28  Acting    ACTOR IN A LEADING ROLE    ACTOR   an0051251
# 1         1  1927/28  Acting    ACTOR IN A LEADING ROLE    ACTOR   an0051252
# 2         1  1927/28  Acting    ACTOR IN A LEADING ROLE    ACTOR  an0051250a
# 3         1  1927/28  Acting    ACTOR IN A LEADING ROLE    ACTOR  an0051250b
# 4         1  1927/28  Acting  ACTRESS IN A LEADING ROLE  ACTRESS   an0051255
#
#                      Film     FilmId                 Name  \
# 0               The Noose  tt0019217  Richard Barthelmess
# 1  The Patent Leather Kid  tt0018253  Richard Barthelmess
# 2        The Last Command  tt0019071        Emil Jannings
# 3    The Way of All Flesh  tt0019553        Emil Jannings
# 4         A Ship Comes In  tt0018389       Louise Dresser
#
#               Nominees NomineeIds Winner  \
# 0  Richard Barthelmess  nm0001932    NaN
# 1  Richard Barthelmess  nm0001932    NaN
# 2        Emil Jannings  nm0417837   True
# 3        Emil Jannings  nm0417837   True
# 4       Louise Dresser  nm0237571    NaN
#
#                                               Detail Note Citation  \
# 0                                      Nickie Elkins  NaN      NaN
# 1                             The Patent Leather Kid  NaN      NaN
# 2  General Dolgorucki [Grand Duke Sergius Alexander]  NaN      NaN
# 3                                   August Schilling  NaN      NaN
# 4                                       Mrs. Pleznik  NaN      NaN
#
#   MultifilmNomination
# 0                True
# 1                True
# 2                True
# 3                True
# 4                 NaN

# %% [markdown]
# **Get Film's Information**

# %%
current_year = datetime.now().year 
# Obtain all the films from 2024
year_start = 2010

oscar_awards_df["YearStart"] = (
    oscar_awards_df["Year"].astype(str).str.split("/").str[0].astype(int))

recent_oscars = oscar_awards_df[ (oscar_awards_df["YearStart"] >= year_start) & (oscar_awards_df["YearStart"] <= current_year - 2) & (oscar_awards_df["FilmId"].notna()) ]
recent_oscars.head()
# Out:
#       Ceremony  Year   Class        CanonicalCategory  \
# 9965        83  2010  Acting  ACTOR IN A LEADING ROLE
# 9966        83  2010  Acting  ACTOR IN A LEADING ROLE
# 9967        83  2010  Acting  ACTOR IN A LEADING ROLE
# 9968        83  2010  Acting  ACTOR IN A LEADING ROLE
# 9969        83  2010  Acting  ACTOR IN A LEADING ROLE
#
#                      Category      NomId                Film     FilmId  \
# 9965  ACTOR IN A LEADING ROLE  an0310760            Biutiful  tt1164999
# 9966  ACTOR IN A LEADING ROLE  an0310761           True Grit  tt1403865
# 9967  ACTOR IN A LEADING ROLE  an0310762  The Social Network  tt1285016
# 9968  ACTOR IN A LEADING ROLE  an0310763   The King's Speech  tt1504320
# 9969  ACTOR IN A LEADING ROLE  an0310764           127 Hours  tt1542344
#
#                  Name         Nominees NomineeIds Winner           Detail  \
# 9965    Javier Bardem    Javier Bardem  nm0000849    NaN            Uxbal
# 9966     Jeff Bridges     Jeff Bridges  nm0000313    NaN  Rooster Cogburn
# 9967  Jesse Eisenberg  Jesse Eisenberg  nm0251986    NaN  Mark Zuckerberg
# 9968      Colin Firth      Colin Firth  nm0000147   True   King George VI
# 9969     James Franco     James Franco  nm0290556    NaN     Aron Ralston
#
#      Note Citation MultifilmNomination  YearStart
# 9965  NaN      NaN                 NaN       2010
# 9966  NaN      NaN                 NaN       2010
# 9967  NaN      NaN                 NaN       2010
# 9968  NaN      NaN                 NaN       2010
# 9969  NaN      NaN                 NaN       2010

# %%
# Get unique FilmId from Oscar List
mask = ~recent_oscars["FilmId"].astype(str).str.startswith("tt")
recent_oscars.loc[mask, "FilmId"].unique()

# check to only get data that we don't have currently have
file_path = 'extracted_data/films_data.csv'
if os.path.exists(file_path):
    stored_film_ids = pd.read_csv(file_path)['imdb_id'].astype(str).unique()
    print(f"Loaded {len(stored_film_ids)} film IDs")
else:
    print(f"File not found: {file_path}")
    stored_film_ids = []  # Or initialize as empty
unique_films_ids = recent_oscars['FilmId'].str[2:].astype(str).unique()

combined_unique = list(set(stored_film_ids) ^ set(unique_films_ids))

# Movie web scraper
# Use the online IMDb interface
ia = IMDb('web')

film_rows = []

for film_id in combined_unique:
    film = ia.get_movie(film_id)
    time.sleep(0.5) # half‑second pause

    if film:
        # Extract budget from business info
        budget = None
        if 'business' in film.keys():
            business = film.get('business', {})
            # Budget is stored as a list in the 'budget' key
            budget_list = business.get('budget', [])
            if budget_list:
                budget = budget_list[0]  # Take first budget entry   

    if film:
        directors = []
        for d in film.get("directors", []):
        # IMDbPY Person objects have .get("name")
            try:
                name = d.get("name")
                if name:
                    directors.append(name)
            except Exception:
                pass

        basic_info = {
            "title": film.get("title"),
            "year": film.get("year"),
            "rating": film.get("rating"),
            "genres": film.get("genres"),
            "runtime": film.get("runtimes"),
            "director": directors,
            "budget": budget,
            "imdb_id": film.movieID
        }
        print("Appending: ", basic_info['title'])
        film_rows.append(basic_info)
    else:
        print("Film was not found:", film_id)

films_information = pd.DataFrame(film_rows)
films_information.head(2)
# Out:
# Loaded 103 film IDs
# Appending:  Tár
# Appending:  Shok
# Appending:  The Dam Keeper
# Appending:  Late Afternoon
# Appending:  The Confession
# Appending:  Free Solo
# Appending:  The Iron Lady
# Appending:  The White Helmets
# Appending:  Vikhod
# Appending:  Mary Poppins Returns
# Appending:  Please Hold
# Appending:  White Earth
# Appending:  Tron: Legacy
# Appending:  Take and Run
# Appending:  Frankenweenie
# Appending:  Little Women
# Appending:  Parasite
# Appending:  Another Round
# Appending:  My Life as a Zucchini
# Appending:  The Wife
# Appending:  Empire of Light
# Appending:  Star Trek Beyond
# Appending:  The Square
# Appending:  Argentina, 1985
# Appending:  Elle
# Appending:  Rocketman
# Appending:  Lion
# Appending:  Joy
# Appending:  45 Years
# Appending:  The Big Sick
# Appending:  Strong Island
# Appending:  A Better Life
# Appending:  The Adventures of Tintin
# Appending:  Three Billboards Outside Ebbing, Missouri
# Appending:  A Quiet Place
# Appending:  Night Ride
# Appending:  Puss in Boots
# Appending:  GasLand
# Appending:  Garden Party
# Appending:  Avengers: Endgame
# Appending:  When We Were Bullies
# Appending:  The Sea Beast
# Appending:  Once Upon a Time... in Hollywood
# Appending:  Pearl
# Appending:  BlacKkKlansman
# Appending:  In Darkness
# Appending:  Pinocchio
# Appending:  The Whale
# Appending:  Cutie and the Boxer
# Appending:  The Lost Thing
# Appending:  Learning to Skateboard in a Warzone (If You're a Girl)
# Appending:  The Illusionist
# Appending:  Footnote
# Appending:  Time Freak
# Appending:  The Invisible War
# Appending:  War Witch
# Appending:  Unstoppable
# Appending:  The Town
# Appending:  Last Day of Freedom
# Appending:  The Tale of The Princess Kaguya
# Appending:  Star Wars: Episode VIII - The Last Jedi
# Appending:  The Boss Baby
# Appending:  The Lone Ranger
# Appending:  Straight Outta Compton
# Appending:  Roma
# Appending:  The Phone Call
# Appending:  Animal Kingdom
# Appending:  A Man Called Ove
# Appending:  Harry Potter and the Deathly Hallows: Part 1
# Appending:  Belfast
# Appending:  On Body and Soul
# Appending:  Mr. Hublot
# Appending:  Nightcrawler
# Appending:  Interstellar
# Appending:  Audible
# Appending:  Licorice Pizza
# Appending:  Watu Wote: All of Us
# Appending:  Minding the Gap
# Appending:  Raju
# Appending:  Incendies
# Appending:  Fire at Sea
# Appending:  Ad Astra
# Appending:  Lincoln
# Appending:  When Marnie Was There
# Appending:  Begin Again
# Appending:  Ralph Breaks the Internet
# Appending:  Open Heart
# Appending:  How Do You Measure a Year?
# Appending:  Adam and Dog
# Appending:  Jim: The James Foley Story
# Appending:  Dogtooth
# Appending:  The Voorman Problem
# Appending:  Toni Erdmann
# Appending:  The Tree of Life
# Appending:  Harriet
# Appending:  What Happened, Miss Simone?
# Appending:  Opera
# Appending:  Alice in Wonderland
# Appending:  Weekends
# Appending:  Knives Out
# Appending:  Bohemian Rhapsody
# Appending:  To Leslie
# Appending:  The Broken Circle Breakdown
# Appending:  Pear Cider and Cigarettes
# Appending:  Kong: Skull Island
# Appending:  Florence Foster Jenkins
# Appending:  God Is the Bigger Elvis
# Appending:  EO
# Appending:  Moonrise Kingdom
# Appending:  Get a Horse!
# Appending:  Saving Face
# Appending:  An Ostrich Told Me the World Is Fake and I Think I Believe It
# Appending:  RRR
# Appending:  Argo
# Appending:  Snow White and the Huntsman
# Appending:  Winter on Fire: Ukraine's Fight for Freedom
# Appending:  Mulan
# Appending:  Flight
# Appending:  The Shore
# Appending:  The Invisible Woman
# Appending:  Joker
# Appending:  Amour
# Appending:  I Am Not Your Negro
# Appending:  Tangled
# Appending:  Despicable Me 2
# Appending:  Rio
# Appending:  The Boy and the World
# Appending:  War for the Planet of the Apes
# Appending:  Gone Girl
# Appending:  Guillermo del Toro's Pinocchio
# Appending:  Richard Jewell
# Appending:  Monsieur Lazhar
# Appending:  Daughter
# Appending:  Mr. Turner
# Appending:  Negative Space
# Appending:  Land of Mine
# Appending:  Beasts of the Southern Wild
# Appending:  The Lady in Number 6: Music Saved My Life
# Appending:  The Jungle Book
# Appending:  King Richard
# Appending:  Madagascar, a Journey Diary
# Appending:  White Eye
# Appending:  Captain Phillips
# Appending:  Beast
# Appending:  The Grandmaster
# Appending:  Phantom Thread
# Appending:  Rogue One: A Star Wars Story
# Appending:  The Dress
# Appending:  Crip Camp
# Appending:  Hitchcock
# Appending:  Feeling Through
# Appending:  Day One
# Appending:  Coco
# Appending:  Just Before Losing Everything
# Appending:  La Luna
# Appending:  Yes-People
# Appending:  Let's Pollute
# Appending:  The Reaper
# Appending:  Detainment
# Appending:  Honeyland
# Appending:  Prologue
# Appending:  The Barber of Birmingham: Foot Soldier of the Civil Rights Movement
# Appending:  Blue Jasmine
# Appending:  Drive
# Appending:  Helium
# Appending:  Over the Moon
# Appending:  Cavedigger
# Appending:  Enemies Within
# Appending:  The Martha Mitchell Effect
# Appending:  12 Years a Slave
# Appending:  Restrepo
# Appending:  Beginners
# Appending:  Stutterer
# Appending:  The Queen of Basketball
# Appending:  Bao
# Appending:  The Wind Rises
# Appending:  The Hobbit: The Battle of the Five Armies
# Appending:  Ascension
# Appending:  A Star Is Born
# Appending:  CODA
# Appending:  The Mitchells vs. the Machines
# Appending:  Sound of Metal
# Appending:  Jackass Presents: Bad Grandpa
# Appending:  Genius Loci
# Appending:  Frozen
# Appending:  All the Money in the World
# Appending:  Star Wars: Episode VII - The Force Awakens
# Appending:  Real Steel
# Appending:  The Hateful Eight
# Appending:  Hair Love
# Appending:  The Wolfman
# Appending:  Can You Ever Forgive Me?
# Appending:  Being the Ricardos
# Appending:  Hail, Caesar!
# Appending:  Racing Extinction
# Appending:  Fire of Love
# Appending:  Django Unchained
# Appending:  Dallas Buyers Club
# Appending:  Everything Everywhere All at Once
# Appending:  Albert Nobbs
# Appending:  Revolting Rhymes Part One
# Appending:  Faces Places
# Appending:  The Fighter
# Appending:  Theeb
# Appending:  My Nephew Emmett
# Appending:  Karama Has No Walls
# Appending:  Borat Subsequent Moviefilm
# Appending:  Better Days
# Appending:  The Imitation Game
# Appending:  The Gatekeepers
# Appending:  Moana
# Appending:  Dune: Part One
# Appending:  Hugo
# Appending:  Call Me by Your Name
# Appending:  Sunday
# Appending:  Hillbilly Elegy
# Appending:  My Year of Dicks
# Appending:  Onward
# Appending:  One Small Step
# Appending:  The Banshees of Inisherin
# Appending:  Eurovision Song Contest: The Story of Fire Saga
# Appending:  The Edge of Democracy
# Appending:  Loving Vincent
# Appending:  Never Look Away
# Appending:  Wolfwalkers
# Appending:  Wild Tales
# Appending:  Fauve
# Appending:  The Martian
# Appending:  The Revenant
# Appending:  Coming 2 America
# Appending:  The Act of Killing
# Appending:  The Longest Daycare
# Appending:  4.1 Miles
# Appending:  House of Gucci
# Appending:  BoksBalet
# Appending:  Shang-Chi and the Legend of the Ten Rings
# Appending:  Jojo Rabbit
# Appending:  All Quiet on the Western Front
# Appending:  The Father
# Appending:  Tell It Like a Woman
# Appending:  Borrowed Time
# Appending:  Spider-Man: No Way Home
# Appending:  Wish 143
# Appending:  Quo Vadis, Aida?
# Appending:  Causeway
# Appending:  Redemption
# Appending:  Bridge of Spies
# Appending:  O.J.: Made in America
# Appending:  Soul
# Appending:  13th
# Appending:  Inocente
# Appending:  Fresh Guacamole
# Appending:  Judas and the Black Messiah
# Appending:  Top Gun: Maverick
# Appending:  Ice Merchants
# Appending:  Buzkashi Boys
# Appending:  Ford v Ferrari
# Appending:  Silence
# Appending:  Creed
# Appending:  The Pirates! Band of Misfits
# Appending:  The Salesman
# Appending:  Extremis
# Appending:  The Disaster Artist
# Appending:  Joanna
# Appending:  One Night in Miami...
# Appending:  Wild
# Appending:  Bardo: False Chronicle of a Handful of Truths
# Appending:  Bridesmaids
# Appending:  Timbuktu
# Appending:  Loveless
# Appending:  Mandela: Long Walk to Freedom
# Appending:  The Silent Child
# Appending:  Henry
# Appending:  Greyhound
# Appending:  Mirror Mirror
# Appending:  West Side Story
# Appending:  ParaNorman
# Appending:  In the Absence
# Appending:  The Lighthouse
# Appending:  Three Songs for Benazir
# Appending:  Shoplifters
# Appending:  Breakthrough
# Appending:  The Big Short
# Appending:  The King's Speech
# Appending:  Bombshell
# Appending:  Outside the Law
# Appending:  Triangle of Sadness
# Appending:  Sister
# Appending:  All That Breathes
# Appending:  Rango
# Appending:  Inception
# Appending:  Our Curse
# Appending:  Gravity
# Appending:  Black Sheep
# Appending:  Ida
# Appending:  Virunga
# Appending:  Chau, Beyond the Lines
# Appending:  Guardians of the Galaxy Vol. 2
# Appending:  Paperman
# Appending:  La femme et le TGV
# Appending:  Mad Max: Fury Road
# Appending:  For Sama
# Appending:  Before Midnight
# Appending:  Les Misérables
# Appending:  The Lost Daughter
# Appending:  Carol
# Appending:  Margin Call
# Appending:  Fifty Shades of Grey
# Appending:  Sicario
# Appending:  Raya and the Last Dragon
# Appending:  Mrs. Harris Goes to Paris
# Appending:  20 Feet from Stardom
# Appending:  Midnight in Paris
# Appending:  Exit Through the Gift Shop
# Appending:  Ivalu
# Appending:  Anna Karenina
# Appending:  Birdman or (The Unexpected Virtue of Ignorance)
# Appending:  Green Book
# Appending:  The Irishman
# Appending:  Spider-Man: Into the Spider-Verse
# Appending:  Le pupille
# Appending:  Steve Jobs
# Appending:  How to Survive a Plague
# Appending:  Dawn of the Planet of the Apes
# Appending:  The Salt of the Earth
# Appending:  Kon-Tiki
# Appending:  True Grit
# Appending:  The Boxtrolls
# Appending:  Crisis Hotline: Veterans Press 1
# Appending:  Timecode
# Appending:  Life, Animated
# Appending:  If Beale Street Could Talk
# Appending:  Judy
# Appending:  Isle of Dogs
# Appending:  Klaus
# Appending:  The Long Goodbye
# Appending:  The Social Network
# Appending:  Hell or High Water
# Appending:  Finding Vivian Maier
# Appending:  Sanjay's Super Team
# Appending:  Ernest & Celestine
# Appending:  Curfew
# Appending:  Boyhood
# Appending:  Promising Young Woman
# Appending:  Jackie
# Appending:  The Kids Are All Right
# Appending:  Claude Lanzmann: Spectres of the Shoah
# Appending:  American Hustle
# Appending:  If a Tree Falls: A Story of the Earth Liberation Front
# Appending:  Molly's Game
# Appending:  Do Not Split
# Appending:  A War
# Appending:  Spotlight
# Appending:  Kung Fu Panda 2
# Appending:  Bullhead
# Appending:  Christopher Robin
# Appending:  The Hobbit: The Desolation of Smaug
# Appending:  RBG
# Appending:  Luca
# Appending:  Undefeated
# Appending:  Ferdinand
# Appending:  Room
# Appending:  Animal Behaviour
# Appending:  I Lost My Body
# Appending:  Omar
# Appending:  Inside Llewyn Davis
# Appending:  The One and Only Ivan
# Appending:  Embrace of the Serpent
# Appending:  Incredibles 2
# Appending:  Into the Woods
# Appending:  Living
# Appending:  Baby Driver
# Appending:  Maleficent
# Appending:  Cartel Land
# Appending:  American Factory
# Appending:  Brave
# Appending:  Jane Eyre
# Appending:  Silent Nights
# Appending:  Kubo and the Two Strings
# Appending:  Don't Look Up
# Appending:  Iron Man 3
# Appending:  Close
# Appending:  Corpus Christi
# Appending:  Wreck-It Ralph
# Appending:  Inside Out
# Appending:  Biutiful
# Appending:  Waste Land
# Appending:  The Ballad of Buster Scruggs
# Appending:  Puss in Boots: The Last Wish
# Appending:  Abacus: Small Enough to Jail
# Appending:  St. Louis Superman
# Appending:  The Mole Agent
# Appending:  Brooklyn
# Appending:  Alone Yet Not Alone
# Appending:  A Single Life
# Appending:  Sing
# Appending:  First Man
# Appending:  A Night at the Garden
# Appending:  The Elephant Whisperers
# Appending:  Saria
# Appending:  Nefta Football Club
# Appending:  Star Wars: Episode IX - The Rise of Skywalker
# Appending:  Tenet
# Appending:  Roman J. Israel, Esq.
# Appending:  News of the World
# Appending:  Carne y arena
# Appending:  Blonde
# Appending:  Period. End of Sentence.
# Appending:  An Irish Goodbye
# Appending:  I, Tonya
# Appending:  Trolls
# Appending:  The Man Who Sold His Skin
# Appending:  Marshall
# Appending:  Hale County This Morning, This Evening
# Appending:  Chico & Rita
# Appending:  Last Men in Aleppo
# Appending:  Ma Rainey's Black Bottom
# Appending:  Traffic Stop
# Appending:  A House Made of Splinters
# Appending:  Hunger Ward
# Appending:  Still Alice
# Appending:  Everything Will Be Okay
# Appending:  Skyfall
# Appending:  Country Strong
# Appending:  The Wolf of Wall Street
# Appending:  The Croods
# Appending:  The Flying Sailor
# Appending:  The Letter Room
# Appending:  Black Panther
# Appending:  Tuba Atlantic
# Appending:  Fantastic Beasts and Where to Find Them
# Appending:  A Cat in Paris
# Appending:  The Master
# Appending:  Philomena
# Appending:  Glass Onion
# Appending:  Last Days in Vietnam
# Appending:  The Tempest
# Appending:  At Eternity's Gate
# Appending:  A Beautiful Day in the Neighborhood
# Appending:  Asad
# Appending:  X-Men: Days of Future Past
# Appending:  We Can't Live Without Cosmos
# Appending:  Victoria & Abdul
# Appending:  The Quiet Girl
# Appending:  The Gruffalo
# Appending:  The Post
# Appending:  Memorable
# Appending:  Prisoners
# Appending:  Strangers No More
# Appending:  Chasing Ice
# Appending:  Get Out
# Appending:  The Neighbors' Window
# Appending:  Joe's Violin
# Appending:  Day & Night
# Appending:  The Ides of March
# Appending:  Brotherhood
# Appending:  Spencer
# Appending:  Writing with Fire
# Appending:  Anomalisa
# Appending:  Salt
# Appending:  La La Land
# Appending:  Ted
# Appending:  Leviathan
# Appending:  Nebraska
# Appending:  13 Hours: The Secret Soldiers of Benghazi
# Appending:  Babylon
# Appending:  Of Fathers and Sons
# Appending:  Boogaloo and Graham
# Appending:  Warrior
# Appending:  Citizenfour
# Appending:  Elvis
# Appending:  The Lobster
# Appending:  Zero Dark Thirty
# Appending:  Frozen II
# Appending:  5 Broken Cameras
# Appending:  Border
# Appending:  How to Train Your Dragon: The Hidden World
# Appending:  Hacksaw Ridge
# Appending:  Tinker Tailor Soldier Spy
# Appending:  The Eleven O'Clock
# Appending:  The Warriors of Qiugang
# Appending:  The Red Suitcase
# Appending:  Pieces of a Woman
# Appending:  The Cave
# Appending:  The Way Back
# Appending:  Another Year
# Appending:  The Tsunami and the Cherry Blossom
# Appending:  The Lego Movie
# Appending:  The Two Popes
# Appending:  The Power of the Dog
# Appending:  Stranger at the Gate
# Appending:  Hidden Figures
# Appending:  Deepwater Horizon
# Appending:  Aftersun
# Appending:  My Week with Marilyn
# Appending:  Da 5 Bloods
# Appending:  On My Mind
# Appending:  The Windshield Wiper
# Appending:  Turning Red
# Appending:  The United States vs. Billie Holiday
# Appending:  A Morning Stroll
# Appending:  Silver Linings Playbook
# Appending:  Bear Story
# Appending:  The Florida Project
# Appending:  A Concerto Is a Conversation
# Appending:  Les Misérables
# Appending:  Minari
# Appending:  Burrow
# Appending:  Paradise Lost 3: Purgatory
# Appending:  The Avengers
# Appending:  Summer of Soul (...Or, When the Revolution Could Not Be Televised)
# Appending:  Feast
# Appending:  The Boy, the Mole, the Fox and the Horse
# Appending:  Anonymous
# Appending:  Free Guy
# Appending:  Avatar: The Way of Water
# Appending:  Collective
# Appending:  The Hobbit: An Unexpected Journey
# Appending:  Wild Life
# Appending:  Cold War
# Appending:  Vice
# Appending:  My Octopus Teacher
# Appending:  Glen Campbell: I'll Be Me
# Appending:  Nomadland
# Appending:  Fences
# Appending:  Na Wewe
# Appending:  Black Swan
# Appending:  Ave Maria
# Appending:  How to Train Your Dragon
# Appending:  Skin
# Appending:  The Eyes of Tammy Faye
# Appending:  Cyrano
# Appending:  Facing Fear
# Appending:  No Time to Die
# Appending:  Blue Valentine
# Appending:  Hell and Back Again
# Appending:  If Anything Happens I Love You
# Appending:  Manchester by the Sea
# Appending:  Parallel Mothers
# Appending:  No
# Appending:  Killing in the Name
# Appending:  Dirty Wars
# Appending:  Ready Player One
# Appending:  A Royal Affair
# Appending:  Cruella
# Appending:  A Girl in the River: The Price of Forgiveness
# Appending:  Transformers: Dark of the Moon
# Appending:  Lou
# Appending:  Mirai
# Appending:  A Shaun the Sheep Movie: Farmageddon
# Appending:  Toy Story 4
# Appending:  Feral
# Appending:  A Love Song for Latasha
# Appending:  Avengers: Infinity War
# Appending:  Her
# Appending:  The Present
# Appending:  The Square
# Appending:  Possessions
# Appending:  Inherent Vice
# Appending:  The Artist
# Appending:  The Hunting Ground
# Appending:  Robin Robin
# Appending:  The Impossible
# Appending:  Doctor Strange
# Appending:  The Grand Budapest Hotel
# Appending:  Kings Point
# Appending:  Lifeboat
# Appending:  Pitääkö mun kaikki hoitaa?
# Appending:  Inside Job
# Appending:  The Girl with the Dragon Tattoo
# Appending:  Two Days, One Night
# Appending:  Mustang
# Appending:  Shaun the Sheep Movie
# Appending:  Unbroken
# Appending:  Allied
# Appending:  Blade Runner 2049
# Appending:  Big Hero 6
# Appending:  Zootopia
# Appending:  Dunkirk
# Appending:  Lone Survivor
# Appending:  The Insult
# Appending:  Marriage Story
# Appending:  1917
# Appending:  Navalny
# Appending:  Time
# Appending:  The Theory of Everything
# Appending:  Toy Story 3
# Appending:  Prison Terminal: The Last Days of Private Jack Hall
# Appending:  Beyond the Lights
# Appending:  Pina
# Appending:  End Game
# Appending:  Selma
# Appending:  Butter Lamp
# Appending:  Youth
# Appending:  Me and My Moulton
# Appending:  The Great Gatsby
# Appending:  Blind Vaysha
# Appending:  Capernaum
# Appending:  Knife Skills
# Appending:  A Fantastic Woman
# Appending:  The Trial of the Chicago 7
# Appending:  The Bigger Picture
# Appending:  Foxcatcher
# Appending:  The Tragedy of Macbeth
# Appending:  Flee
# Appending:  The Danish Girl
# Appending:  Suicide Squad
# Appending:  DeKalb Elementary
# Appending:  Affairs of the Art
# Appending:  Nightmare Alley
# Appending:  Lead Me Home
# Appending:  All the Beauty and the Bloodshed
# Appending:  Women Talking
# Appending:  Star Trek Into Darkness
# Appending:  Hereafter
# Appending:  I Am Love
# Appending:  Death of a Shadow
# Appending:  The Book Thief
# Appending:  Emma.
# Appending:  Trumbo
# Appending:  The Breadwinner
# Appending:  Four Good Days
# Appending:  Whiplash
# Appending:  Spectre
# Appending:  Solo: A Star Wars Story
# Appending:  The Red Turtle
# Appending:  A Separation
# Appending:  World of Tomorrow
# Appending:  Ex Machina
# Appending:  Rise of the Planet of the Apes
# Appending:  Life of Pi
# Appending:  Mondays at Racine
# Appending:  How to Train Your Dragon 2
# Appending:  Loving
# Appending:  The Shape of Water
# Appending:  Moonlight
# Appending:  Heaven is a Traffic Jam on the 405
# Appending:  Mank
# Appending:  Kitbull
# Appending:  Marguerite
# Appending:  Attica
# Appending:  tick, tick... BOOM!
# Appending:  127 Hours
# Appending:  God of Love
# Appending:  Nocturnal Animals
# Appending:  The Muppets
# Appending:  In a Better World
# Appending:  The Judge
# Appending:  Arrival
# Appending:  Iron Man 2
# Appending:  Beauty and the Beast
# Appending:  Passengers
# Appending:  Captain America: The Winter Soldier
# Appending:  Logan
# Appending:  W.E.
# Appending:  Life Overtakes Me
# Appending:  Sun Come Up
# Appending:  War Horse
# Appending:  The Help
# Appending:  The Descendants
# Appending:  Madre
# Appending:  Prometheus
# Appending:  August: Osage County
# Appending:  The Missing Picture
# Appending:  The Greatest Showman
# Appending:  Moneyball
# Appending:  20th Century Women
# Appending:  Missing Link
# Appending:  Piper
# Appending:  Black Panther: Wakanda Forever
# Appending:  The 100 Year-Old Man Who Climbed Out the Window and Disappeared
# Appending:  Encanto
# Appending:  Mary Queen of Scots
# Appending:  The Fabelmans
# Appending:  The Favourite
# Appending:  Heroin(e)
# Appending:  Marcel the Shell with Shoes On
# Appending:  Room on the Broom
# Appending:  Wonder
# Appending:  Barney's Version
# Appending:  Dear Basketball
# Appending:  Guardians of the Galaxy
# Appending:  Captain Fantastic
# Appending:  The Crush
# Appending:  All Is Lost
# Appending:  Darkest Hour
# Appending:  The Worst Person in the World
# Appending:  Aya
# Appending:  Parvaneh
# Appending:  The Lion King
# Appending:  Cinderella
# Appending:  First Reformed
# Appending:  The Midnight Sky
# Appending:  Two Distant Strangers
# Appending:  The White Tiger
# Appending:  Song of the Sea
# Appending:  Son of Saul
# Appending:  Love and Monsters
# Appending:  Tanna
# Appending:  Body Team 12
# Appending:  Pentecost
# Appending:  Poster Girl
# Appending:  Drive My Car
# Appending:  Mudbound
# Appending:  The Hunt
# Appending:  The Batman
# Appending:  Sully
# Appending:  Icarus
# Appending:  Tangerines
# Appending:  The Sessions
# Appending:  Maleficent: Mistress of Evil
# Appending:  Harry Potter and the Deathly Hallows: Part 2
# Appending:  The Fantastic Flying Books of Mr. Morris Lessmore
# Appending:  Saving Mr. Banks
# Appending:  Searching for Sugar Man
# Appending:  Edith+Eddie
# Appending:  Rabbit Hole
# Appending:  The Great Beauty
# Appending:  Watani: My Homeland
# Appending:  Lady Bird
# Appending:  Extremely Loud & Incredibly Close
# Appending:  Incident in New Baghdad
# Appending:  The Hand of God
# Appending:  Colette
# Appending:  Walk Run Cha-Cha
# Appending:  That Wasn't Me
# Appending:  The Life Ahead
# Appending:  Welcome to Chechnya
# Appending:  A Sister
# Appending:  The Look of Silence
# Appending:  Lunana: A Yak in the Classroom
# Appending:  American Sniper
# Appending:  Winter's Bone
# Appending:  Pain and Glory
# Appending:  Head Over Heels
# Appending:  Amy
#   title  year rating                        genres runtime           director  \
# 0   Tár  2022    7.4                [Drama, Music]   [158]       [Todd Field]
# 1  Shok  2015    7.9  [Short, Drama, History, War]    [21]  [Jamie Donoughue]
#
#   budget   imdb_id
# 0   None  14444726
# 1   None   4273570

# %% [markdown]
# **Get Streaming Services where Films are Available**

# %%
import time
import httpx

def safe_search(title, country="US", lang="en", count=5, retries=5):
    for attempt in range(retries):
        try:
            return search(title, country, lang, count)
        except httpx.HTTPStatusError as e:
            if e.response.status_code == 429:
                wait = min(2 ** attempt, 30)  # cap at 30 seconds
                print(f"Rate limited for '{title}'. Waiting {wait} seconds...")
                time.sleep(wait)
            else:
                raise
    print(f"Failed to fetch after retries: {title}")
    return []


film_identifiers = recent_oscars[["Film", "FilmId"]].drop_duplicates()

film_streaming_options = []

for row in film_identifiers.itertuples(index=False):
    film_name = row.Film
    film_id = row.FilmId

    # Use the safe wrapper
    results = safe_search(film_name, "US", "en", 5)

    target_imdb = film_id
    found = False

    for movie in results:
        if movie.imdb_id == target_imdb:
            found = True
            film_streaming_option = {
                "Name": movie.title,
                "Release Year": movie.release_year,
                "Poster": movie.poster,
                "IMdbId": movie.imdb_id,
                "Streaming": [offer.package.name for offer in movie.offers if offer.monetization_type == 'FLATRATE'],
                "Rent": [f"{offer.package.name} (${offer.price_value})" for offer in movie.offers if offer.monetization_type == 'RENT'],
                "Buy": [f"{offer.package.name} (${offer.price_value})" for offer in movie.offers if offer.monetization_type == 'BUY']
            }
            film_streaming_options.append(film_streaming_option)

    if not found:
        print(f"FilmId was not found: {film_id}")

    print(f"Film: {film_name}, ID: {film_id}")

    # Optional: slow down slightly to avoid bursts
    time.sleep(0.5)

film_streaming_options = pd.DataFrame(film_streaming_options)
# Out:
# Film: Biutiful, ID: tt1164999
# Film: True Grit, ID: tt1403865
# Film: The Social Network, ID: tt1285016
# Film: The King's Speech, ID: tt1504320
# Film: 127 Hours, ID: tt1542344
# Film: The Fighter, ID: tt0964517
# Film: Winter's Bone, ID: tt1399683
# Film: The Town, ID: tt0840361
# Film: The Kids Are All Right, ID: tt0842926
# Film: Rabbit Hole, ID: tt0935075
# Film: Black Swan, ID: tt0947798
# Film: Blue Valentine, ID: tt1120985
# Film: Animal Kingdom, ID: tt1313092
# Film: How to Train Your Dragon, ID: tt0892769
# Film: The Illusionist, ID: tt0775489
# Film: Toy Story 3, ID: tt0435761
# Film: Alice in Wonderland, ID: tt1014759
# Film: Harry Potter and the Deathly Hallows Part 1, ID: tt0926084
# Film: Inception, ID: tt1375666
# Film: I Am Love, ID: tt1226236
# Film: The Tempest, ID: tt1274300
# Film: Exit through the Gift Shop, ID: tt1587707
# Film: Gasland, ID: tt1558250
# Film: Inside Job, ID: tt1645089
# Film: Restrepo, ID: tt1559549
# Film: Waste Land, ID: tt1268204
# FilmId was not found: tt1684897
# Film: Killing in the Name, ID: tt1684897
# FilmId was not found: tt1505384
# Film: Poster Girl, ID: tt1505384
# FilmId was not found: tt1754549
# Film: Strangers No More, ID: tt1754549
# FilmId was not found: tt1621975
# Film: Sun Come Up, ID: tt1621975
# FilmId was not found: tt1744887
# Film: The Warriors of Qiugang, ID: tt1744887
# Film: Dogtooth, ID: tt1379182
# Film: In a Better World, ID: tt1340107
# Film: Incendies, ID: tt1255953
# Film: Outside the Law (Hors-la-loi), ID: tt1229381
# Film: Barney's Version, ID: tt1423894
# Film: The Way Back, ID: tt1023114
# Film: The Wolfman, ID: tt0780653
# Film: Country Strong, ID: tt1555064
# Film: Tangled, ID: tt0398286
# FilmId was not found: tt1620446
# Film: Day & Night, ID: tt1620446
# Film: The Gruffalo, ID: tt1461418
# FilmId was not found: tt1470652
# Film: Let's Pollute, ID: tt1470652
# FilmId was not found: tt1669698
# Film: The Lost Thing, ID: tt1669698
# FilmId was not found: tt1590114
# Film: Madagascar, carnet de voyage (Madagascar, a Journey Diary), ID: tt1590114
# FilmId was not found: tt1687903
# Film: The Confession, ID: tt1687903
# FilmId was not found: tt1509756
# Film: The Crush, ID: tt1509756
# FilmId was not found: tt1631323
# Film: God of Love, ID: tt1631323
# FilmId was not found: tt1764508
# Film: Na Wewe, ID: tt1764508
# FilmId was not found: tt1518330
# Film: Wish 143, ID: tt1518330
# Film: Wicked, ID: tt1262426
# Film: Emilia Pérez, ID: tt20221436
# Film: The Substance, ID: tt17526714
# Film: I'm Still Here, ID: tt14961016
# Film: Flow, ID: tt4772188
# Film: Inside Out 2, ID: tt22022452
# Film: Memoir of a Snail, ID: tt23770030
# Film: Wallace & Gromit: Vengeance Most Fowl, ID: tt17163970
# Film: The Wild Robot, ID: tt29623480
# Film: Beautiful Men, ID: tt30835281
# FilmId was not found: tt28768883
# Film: In the Shadow of the Cypress, ID: tt28768883
# FilmId was not found: tt31888603
# Film: Magic Candies, ID: tt31888603
# Film: Wander to Wonder, ID: tt28768679
# Film: Yuck!, ID: tt28356173
# Film: Dune: Part Two, ID: tt15239678
# Film: Maria, ID: tt22893404
# Film: Nosferatu, ID: tt5040012
# FilmId was not found: tt9218128
# Film: Gladiator II, ID: tt9218128
# Film: Black Box Diaries, ID: tt30227076
# Film: No Other Land, ID: tt30953759
# Film: Porcelain War, ID: tt30294282
# Film: Soundtrack to a Coup d'Etat, ID: tt14452174
# Film: Sugarcane, ID: tt30319854
# FilmId was not found: tt33385063
# Film: Death by Numbers, ID: tt33385063
# Film: I Am Ready, Warden, ID: tt31556921
# FilmId was not found: tt27990245
# Film: Incident, ID: tt27990245
# Film: Instruments of a Beating Heart, ID: tt32280470
# Film: The Only Girl in the Orchestra, ID: tt29497240
# Film: The Girl with the Needle, ID: tt10236164
# Film: The Seed of the Sacred Fig, ID: tt32178949
# Film: A Different Man, ID: tt21097228
# Film: The Six Triple Eight, ID: tt24458622
# Film: Elton John: Never Too Late, ID: tt20316978
# Film: Nickel Boys, ID: tt23055660
# FilmId was not found: tt27655666
# Film: A Lien, ID: tt27655666
# Film: Anuja, ID: tt27654431
# FilmId was not found: tt19837932
# Film: I'm Not a Robot, ID: tt19837932
# FilmId was not found: tt15802124
# Film: The Last Ranger, ID: tt15802124
# FilmId was not found: tt20519854
# Film: The Man Who Could Not Remain Silent, ID: tt20519854
# Film: Alien: Romulus, ID: tt18412256
# Film: Better Man, ID: tt14260836
# Film: Kingdom of the Planet of the Apes, ID: tt11389872
# Film: September 5, ID: tt28082769

# %%
# Paths
films_path = "extracted_data/films_data.csv"
oscars_path = "extracted_data/oscars_data.csv"
streaming_path = "extracted_data/streaming_data.csv"

# --- FILMS DATA ---
if not os.path.exists(films_path):
    # File doesn't exist → create it
    films_information.to_csv(films_path, index=False)
    print(f"Films CSV file has been created. Path: {films_path}")
else:
    # File exists → update only if needed
    if not films_information.empty:
        existing_ids = pd.read_csv(films_path)['imdb_id'].astype(str).unique()
        new_rows = films_information[~films_information['imdb_id'].astype(str).isin(existing_ids)]

        if not new_rows.empty:
            new_rows.to_csv(films_path, mode='a', header=False, index=False)
            print(f"Films CSV file has been upated with new films information. Path: {films_path}")
    else:
        print("Film CSV requires no new information.")

# --- OSCARS DATA ---
recent_oscars.to_csv(oscars_path, index=False)

# --- FILM STREAMING DATA ---
film_streaming_options.to_csv(streaming_path, index=False)
# Out:
# Films CSV file has been upated with new films information. Path: extracted_data/films_data.csv
